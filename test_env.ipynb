# %%
import sys

print("Python executable:")
print(sys.executable)

assert ".venv" in sys.executable, """
You are NOT using the assignment virtual environment.

Select kernel:
  4543 Geo (.venv)
"""
# Out:
# Python executable:
# /Users/griffin/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/bin/python
