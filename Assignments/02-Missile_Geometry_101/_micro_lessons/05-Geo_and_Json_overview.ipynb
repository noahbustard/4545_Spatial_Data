# %% [markdown]
# ## 05 - Geojson / Json Intermediate Review
#
#
# The file [world_cities_fixed.json](../data/world_cities_fixed.json) has thousands of cities but they are in a json format that doesn't have the correct format for GeoJson. It doesn't have to be GeoJson, as we can use other libraries to generate points or lines using the provided coordinates, but I want to go over creating a couple of things:
#
# 1. A dictionary that organizes each city by time zone
# 2. A set of GeoJson files where one file has all the cities in a single time zone in a GeoJson feature collection format.
#
# I'm making the individual files so you can see a json file get processed into a GeoJson file, plus after they are converted, you can view them easily with [GeoJson.io](https://GeoJson.io) and of course Folium (Folium has other ways to display spatial features aside from GeoJson).
#
# > Notice that the [world_cities_fixed.json](../data/world_cities_fixed.json) file is just a json file that has point data for cities. What it doesn't have is the country in which each city exists. However, we have the worlds country polygons! And with some spatial math, we can assign a city to a country or vice versa. This will be a later project or lesson.

# %% [markdown]
# ## Run Cell Below First
#
# The cell below prints output so it looks organized. It uses a "generator" that "yields" step numbers along with a message and outputs them in a python rich Panel.

# %%
from rich.console import Console
from rich.panel import Panel
from rich import print
console = Console()

# Run this first so I can print "Step 1-------, Step 2-----" with print messages to make the output 
def stepper(width=60, start=1):
    step = start
    while True:
        message = yield
        block = f"Step {step} " + "-" * width
        if message:
            block += f"\n   ↳ {message}"
        step += 1
        yield block
        
def stp(s,msg,content):
    next(s)
    
    panel_styled = Panel(
        f"[b #555555]Output:[/b #555555] \n\n{content}",
        title=f"[b #FF00FF]{msg}[/b #FF00FF]",
        # subtitle="[dim]Status: Active[/dim]",
        border_style="white",
        title_align="left",
        width=100 # Optional: set a specific width
    )
    console.print(panel_styled)

# %% [markdown]
# ### Json Review(ish)

# %%
"""
Understanding our world_cities_fixed file.
"""
s = stepper()             # Prime the generator

# Below is an example object for a single city

single_city = {
    "city-name": "Tokyo",
    "lat": "35.6895",
    "lon": "139.69171",
    "time-zone": "Asia/Tokyo",
}

stp(s,"Printing a key from object",single_city["city-name"])

# Notice the next example with three cities. It adds commas between the objects, and square brackets to show a list.
cities = [
    {
        "city-name": "Tokyo",
        "lat": "35.6895",
        "lon": "139.69171",
        "time-zone": "Asia/Tokyo",
    },
    {
        "city-name": "Paris",
        "lat": "48.85341",
        "lon": "2.3488",
        "time-zone": "Europe/Paris",
    },
    {
        "city-name": "London",
        "lat": "51.50853",
        "lon": "-0.12574",
        "time-zone": "Europe/London",
    },
]

# Print out the lat, lon for Paris:
output = cities[1]["lat"],cities[1]["lon"]
stp(s,"Printing a key from an object thats in a list",output)

# Format the output
formatted = f"Location for: {cities[1]["city-name"]} = lat:{cities[1]["lat"]},lon:{cities[1]["lon"]}"
stp(s,"Printing a key from an object thats in a list but formatted",formatted)


# Now lets process the three cities with a for loop.
# I cast the "city" to a string so I can print it in my fancy box below.
output = ""
for city in cities:
    output += str(city) +"\n"

stp(s,"Printing each object in a list",output)

# Notice that each object prints out to the screen as a whole object, lets just print the city-name and time zone

output = ""
for city in cities:
    output += f"{city["city-name"]} is in {city['time-zone']}\n"

stp(s,"Printing specific items from each object",output)
# Out:
# ╭─ Printing a key from object ─────────────────────────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ Tokyo                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Printing a key from an object thats in a list ──────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ ('48.85341', '2.3488')                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Printing a key from an object thats in a list but formatted ────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ Location for: Paris = lat:48.85341,lon:2.3488                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Printing each object in a list ─────────────────────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ {'city-name': 'Tokyo', 'lat': '35.6895', 'lon': '139.69171', 'time-zone': 'Asia/Tokyo'}          │
# │ {'city-name': 'Paris', 'lat': '48.85341', 'lon': '2.3488', 'time-zone': 'Europe/Paris'}          │
# │ {'city-name': 'London', 'lat': '51.50853', 'lon': '-0.12574', 'time-zone': 'Europe/London'}      │
# │                                                                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ Printing specific items from each object ───────────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ Tokyo is in Asia/Tokyo                                                                           │
# │ Paris is in Europe/Paris                                                                         │
# │ London is in Europe/London                                                                       │
# │                                                                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### Processing All of World Cities

# %%
# If I want to print all the values from the world_cities_fixed.json file, I can do the following:
from pathlib import Path
import sys
import json

cwd = Path.cwd()

target = cwd.parent / "data" / "world_cities_fixed.json"

exists = target.exists()
if not exists:
    print(f"Error: cannot find file: {target}")
    sys.exit()
    
with open(target) as f:
    data = json.load(f)
    
output = len(data)
stp(s,"Number of Cities",str(output))

output = data[:20]
stp(s,"First 20 Cities",str(output))
# Out:
# ╭─ Number of Cities ───────────────────────────────────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ 149102                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─ First 20 Cities ────────────────────────────────────────────────────────────────────────────────╮
# │ Output:                                                                                          │
# │                                                                                                  │
# │ [{'city-name': 'El Tarter', 'lat': '42.57952', 'lon': '1.65362', 'time-zone': 'Europe/Andorra'}, │
# │ {'city-name': 'Sant Julia de Loria', 'lat': '42.46372', 'lon': '1.49129', 'time-zone':           │
# │ 'Europe/Andorra'}, {'city-name': 'Pas de la Casa', 'lat': '42.54277', 'lon': '1.73361',          │
# │ 'time-zone': 'Europe/Andorra'}, {'city-name': 'Ordino', 'lat': '42.55623', 'lon': '1.53319',     │
# │ 'time-zone': 'Europe/Andorra'}, {'city-name': 'les Escaldes', 'lat': '42.50729', 'lon':          │
# │ '1.53414', 'time-zone': 'Europe/Andorra'}, {'city-name': 'la Massana', 'lat': '42.54499', 'lon': │
# │ '1.51483', 'time-zone': 'Europe/Andorra'}, {'city-name': 'Encamp', 'lat': '42.53474', 'lon':     │
# │ '1.58014', 'time-zone': 'Europe/Andorra'}, {'city-name': 'Canillo', 'lat': '42.5676', 'lon':     │
# │ '1.59756', 'time-zone': 'Europe/Andorra'}, {'city-name': 'Arinsal', 'lat': '42.57205', 'lon':    │
# │ '1.48453', 'time-zone': 'Europe/Andorra'}, {'city-name': 'Andorra la Vella', 'lat': '42.50779',  │
# │ 'lon': '1.52109', 'time-zone': 'Europe/Andorra'}, {'city-name': 'Umm al Qaywayn', 'lat':         │
# │ '25.56473', 'lon': '55.55517', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Ras al-Khaimah',       │
# │ 'lat': '25.78953', 'lon': '55.9432', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Muzayri`',       │
# │ 'lat': '23.14355', 'lon': '53.7881', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Khawr Fakkan',   │
# │ 'lat': '25.33132', 'lon': '56.34199', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Dubai', 'lat':  │
# │ '25.0657', 'lon': '55.17128', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Dibba Al-Fujairah',     │
# │ 'lat': '25.59246', 'lon': '56.26176', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Dibba Al-Hisn', │
# │ 'lat': '25.61955', 'lon': '56.27291', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Sharjah',       │
# │ 'lat': '25.33737', 'lon': '55.41206', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Ar Ruways',     │
# │ 'lat': '24.11028', 'lon': '52.73056', 'time-zone': 'Asia/Dubai'}, {'city-name': 'Al Fujayrah',   │
# │ 'lat': '25.11641', 'lon': '56.34141', 'time-zone': 'Asia/Dubai'}]                                │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Create Files
#
# Remember we are doing the following:
#
# 1. A dictionary that organizes each city by time zone
# 2. A set of GeoJson files where one file has all the cities in a single time zone in a GeoJson feature collection format.

# %% [markdown]
# ## Create City By Time Zone
#
# This snippet will create a dictionary that stores the cities in a json object where the `time-zone` is the key.

# %%
import json

with open("../data/world_cities_fixed.json","r") as f:
    cities = json.load(f)
    
    
new_city_dict = {}
for city in cities:
    tz = city['time-zone']
    del city['time-zone']
    if not tz in new_city_dict:
        new_city_dict[tz] = []
    
    
    new_city_dict[tz].append(city)

with open("../data/world_cities_by_time-zone.json","w") as f:
    json.dump(new_city_dict,f,indent=2)

# %% [markdown]
# # Create GeoJson Point Files
#
# - One file per time zone
# - Folder will be in `../Data/WorldCitiesGeo/....`

# %%
## Here we open the file and print the timezone and length of the list it points to

import json

with open("../data/world_cities_by_time-zone.json","r") as f:
    cities = json.load(f)
    
for timezone,citylist in cities.items():
    print(timezone,len(citylist))
# Out:
# Europe/Andorra 10
# Asia/Dubai 14
# Asia/Kabul 311
# America/Antigua 9
# America/Anguilla 14
# Europe/Tirane 355
# Asia/Yerevan 311
# Africa/Luanda 38
# Antarctica/McMurdo 1
# America/Argentina/Buenos_Aires 138
# America/Argentina/Cordoba 505
# America/Argentina/San_Juan 21
# America/Argentina/Salta 135
# America/Argentina/Jujuy 24
# America/Argentina/Tucuman 17
# America/Argentina/Rio_Gallegos 15
# America/Argentina/La_Rioja 21
# America/Argentina/Mendoza 18
# America/Argentina/San_Luis 17
# America/Argentina/Ushuaia 3
# America/Argentina/Catamarca 56
# Pacific/Pago_Pago 14
# Europe/Vienna 1691
# Australia/Perth 239
# Australia/Adelaide 182
# Australia/Darwin 16
# Australia/Brisbane 239
# Australia/Sydney 593
# Australia/Melbourne 427
# Australia/Hobart 67
# Australia/Currie 1
# Australia/Broken_Hill 1
# America/Aruba 1
# Europe/Mariehamn 16
# Asia/Baku 173
# Europe/Sarajevo 263
# America/Barbados 10
# Asia/Dhaka 109
# Europe/Brussels 546
# Africa/Ouagadougou 56
# Europe/Sofia 284
# Asia/Bahrain 9
# Africa/Bujumbura 19
# Africa/Porto-Novo 35
# America/St_Barthelemy 1
# Atlantic/Bermuda 2
# Asia/Brunei 5
# America/La_Paz 153
# America/Kralendijk 7
# America/Fortaleza 358
# America/Recife 103
# America/Belem 52
# America/Maceio 99
# America/Manaus 39
# America/Bahia 176
# America/Santarem 14
# America/Araguaina 7
# America/Noronha 2
# America/Sao_Paulo 1074
# America/Cuiaba 24
# America/Campo_Grande 35
# America/Rio_Branco 13
# America/Porto_Velho 11
# America/Eirunepe 3
# America/Boa_Vista 1
# America/Nassau 25
# Asia/Thimphu 25
# Africa/Gaborone 86
# Europe/Minsk 262
# America/Belize 12
# America/Vancouver 93
# America/Toronto 416
# America/Edmonton 116
# America/Halifax 35
# America/Winnipeg 38
# America/Regina 51
# America/Atikokan 1
# America/St_Johns 25
# America/Moncton 22
# America/Dawson_Creek 4
# America/Iqaluit 2
# America/Creston 1
# America/Yellowknife 5
# America/Fort_Nelson 1
# America/Cambridge_Bay 2
# America/Glace_Bay 3
# America/Whitehorse 2
# America/Goose_Bay 2
# America/Inuvik 1
# America/Pangnirtung 1
# America/Rankin_Inlet 1
# America/Blanc-Sablon 2
# America/Swift_Current 1
# America/Thunder_Bay 1
# America/Detroit 435
# America/Dawson 1
# Indian/Cocos 1
# Africa/Lubumbashi 43
# Africa/Kinshasa 26
# Africa/Bangui 36
# Africa/Brazzaville 19
# Europe/Zurich 1385
# Europe/Rome 9901
# Africa/Abidjan 119
# Pacific/Rarotonga 1
# America/Santiago 135
# Pacific/Easter 1
# Africa/Douala 123
# Asia/Shanghai 14059
# Asia/Urumqi 751
# Asia/Yakutsk 83
# America/Bogota 933
# America/Costa_Rica 131
# America/Havana 183
# Atlantic/Cape_Verde 25
# America/Curacao 4
# Indian/Christmas 1
# Asia/Nicosia 80
# Europe/Prague 1290
# Europe/Berlin 10543
# Europe/Busingen 1
# Africa/Djibouti 13
# Europe/Copenhagen 340
# America/Dominica 17
# America/Santo_Domingo 206
# Africa/Algiers 259
# America/Guayaquil 119
# Pacific/Galapagos 3
# Europe/Tallinn 94
# Africa/Cairo 136
# Africa/El_Aaiun 4
# Africa/Casablanca 243
# Africa/Asmara 12
# Europe/Madrid 6809
# Atlantic/Canary 99
# Europe/Lisbon 554
# Africa/Ceuta 2
# Africa/Addis_Ababa 107
# Europe/Helsinki 453
# Pacific/Fiji 7
# Atlantic/Stanley 1
# Pacific/Chuuk 38
# Pacific/Kosrae 5
# Pacific/Pohnpei 9
# Atlantic/Faroe 15
# Europe/Paris 8600
# Africa/Libreville 27
# Europe/London 4332
# America/Grenada 7
# Asia/Tbilisi 105
# America/Cayenne 18
# Europe/Guernsey 8
# Africa/Accra 72
# Europe/Gibraltar 1
# America/Godthab 13
# Africa/Banjul 70
# Africa/Conakry 41
# America/Guadeloupe 25
# Africa/Malabo 22
# Europe/Athens 1077
# Atlantic/South_Georgia 1
# America/Guatemala 342
# Pacific/Guam 21
# Africa/Bissau 14
# America/Guyana 15
# Asia/Hong_Kong 17
# America/Tegucigalpa 419
# Europe/Zagreb 721
# America/Port-au-Prince 102
# Europe/Budapest 873
# Asia/Jakarta 6407
# Asia/Makassar 2455
# Asia/Jayapura 161
# Asia/Pontianak 70
# Europe/Dublin 352
# Asia/Jerusalem 157
# Europe/Isle_of_Man 21
# Asia/Kolkata 3450
# Asia/Kathmandu 66
# Asia/Rangoon 75
# Asia/Baghdad 134
# Asia/Tehran 441
# Atlantic/Reykjavik 33
# Europe/Jersey 2
# America/Jamaica 90
# Asia/Amman 138
# Asia/Tokyo 779
# Africa/Nairobi 112
# Asia/Bishkek 82
# Asia/Dushanbe 90
# Asia/Phnom_Penh 130
# Pacific/Tarawa 14
# Pacific/Kiritimati 4
# Indian/Comoro 84
# America/St_Kitts 14
# Asia/Pyongyang 79
# Asia/Seoul 175
# Asia/Kuwait 23
# America/Cayman 6
# Asia/Oral 28
# Asia/Aqtau 12
# Asia/Aqtobe 12
# Asia/Almaty 185
# Asia/Qyzylorda 27
# Asia/Vientiane 52
# Asia/Beirut 33
# America/St_Lucia 12
# Europe/Vaduz 11
# Asia/Colombo 72
# Africa/Monrovia 19
# Africa/Maseru 12
# Europe/Vilnius 122
# Europe/Luxembourg 137
# Europe/Riga 133
# Africa/Tripoli 53
# Europe/Monaco 6
# Europe/Chisinau 72
# Europe/Kiev 970
# Europe/Podgorica 37
# America/Marigot 1
# Indian/Antananarivo 122
# Pacific/Majuro 23
# Pacific/Kwajalein 2
# Europe/Skopje 199
# Africa/Bamako 62
# Asia/Hovd 88
# Asia/Ulaanbaatar 212
# Asia/Choibalsan 27
# Asia/Macau 1
# Pacific/Saipan 2
# America/Martinique 20
# Africa/Nouakchott 20
# America/Montserrat 3
# Europe/Malta 69
# Indian/Mauritius 96
# Indian/Maldives 23
# Africa/Blantyre 36
# America/Monterrey 227
# America/Mexico_City 4313
# America/Matamoros 13
# America/Merida 138
# America/Cancun 32
# America/Hermosillo 89
# America/Chihuahua 52
# America/Mazatlan 191
# America/Tijuana 71
# America/Bahia_Banderas 5
# America/Ojinaga 3
# Asia/Kuala_Lumpur 145
# Asia/Kuching 26
# Africa/Maputo 26
# Africa/Windhoek 43
# Pacific/Noumea 29
# Africa/Niamey 45
# Pacific/Norfolk 1
# Africa/Lagos 908
# America/Managua 128
# Europe/Amsterdam 1395
# Europe/Oslo 540
# Pacific/Nauru 8
# Pacific/Niue 1
# Pacific/Auckland 137
# Pacific/Chatham 1
# Asia/Muscat 30
# America/Panama 596
# America/Lima 1290
# Pacific/Marquesas 2
# Pacific/Gambier 1
# Pacific/Tahiti 33
# Pacific/Port_Moresby 39
# Pacific/Bougainville 4
# Asia/Manila 4460
# Asia/Karachi 440
# Europe/Warsaw 2823
# America/Miquelon 2
# Pacific/Pitcairn 1
# America/Puerto_Rico 219
# Asia/Gaza 23
# Asia/Hebron 300
# Atlantic/Madeira 21
# Atlantic/Azores 16
# Pacific/Palau 18
# America/Asuncion 142
# Asia/Qatar 17
# Indian/Reunion 23
# Europe/Bucharest 4571
# Europe/Belgrade 457
# Europe/Moscow 2690
# Asia/Yekaterinburg 567
# Europe/Kirov 67
# Europe/Kaliningrad 33
# Europe/Volgograd 113
# Europe/Samara 86
# Europe/Ulyanovsk 39
# Europe/Astrakhan 34
# Asia/Novokuznetsk 66
# Asia/Tomsk 27
# Asia/Krasnoyarsk 124
# Asia/Barnaul 120
# Asia/Omsk 56
# Asia/Novosibirsk 52
# Asia/Irkutsk 162
# Asia/Chita 63
# Asia/Vladivostok 151
# Asia/Kamchatka 13
# Asia/Magadan 26
# Asia/Sakhalin 35
# Asia/Anadyr 8
# Africa/Kigali 14
# Asia/Riyadh 92
# Pacific/Guadalcanal 8
# Indian/Mahe 9
# Africa/Khartoum 71
# Europe/Stockholm 821
# Asia/Singapore 1
# Atlantic/St_Helena 3
# Europe/Ljubljana 301
# Arctic/Longyearbyen 2
# Europe/Bratislava 150
# Africa/Freetown 84
# Europe/San_Marino 9
# Africa/Dakar 59
# Africa/Mogadishu 54
# America/Paramaribo 13
# Africa/Juba 34
# Africa/Sao_Tome 3
# America/El_Salvador 100
# America/Lower_Princes 4
# Asia/Damascus 287
# Africa/Mbabane 23
# America/Grand_Turk 1
# Africa/Ndjamena 47
# Indian/Kerguelen 1
# Africa/Lome 21
# Asia/Bangkok 974
# Pacific/Fakaofo 3
# Asia/Dili 16
# Asia/Ashgabat 31
# Africa/Tunis 143
# Pacific/Tongatapu 7
# Europe/Istanbul 1912
# America/Port_of_Spain 22
# Pacific/Funafuti 8
# Asia/Taipei 34
# Africa/Dar_es_Salaam 287
# Europe/Simferopol 364
# Europe/Zaporozhye 108
# Europe/Uzhgorod 68
# Africa/Kampala 140
# America/Chicago 5350
# America/New_York 7403
# America/Indiana/Indianapolis 252
# America/Indiana/Vincennes 9
# America/Indiana/Tell_City 2
# America/Kentucky/Louisville 45
# America/Indiana/Marengo 1
# America/Indiana/Petersburg 1
# America/Indiana/Vevay 1
# America/Kentucky/Monticello 1
# America/Indiana/Knox 4
# America/Indiana/Winamac 1
# America/Menominee 11
# America/Phoenix 197
# America/Los_Angeles 1775
# America/Denver 821
# America/Juneau 3
# America/Sitka 4
# America/Metlakatla 1
# America/Boise 77
# America/North_Dakota/Beulah 3
# America/North_Dakota/Center 1
# America/North_Dakota/New_Salem 1
# Pacific/Honolulu 124
# America/Anchorage 54
# America/Nome 5
# America/Adak 2
# America/Montevideo 123
# Asia/Samarkand 94
# Asia/Tashkent 80
# Europe/Vatican 1
# America/St_Vincent 9
# America/Caracas 367
# America/Tortola 1
# America/St_Thomas 3
# Asia/Ho_Chi_Minh 612
# Pacific/Efate 8
# Pacific/Wallis 3
# Pacific/Apia 24
# Asia/Aden 301
# Indian/Mayotte 17
# Africa/Johannesburg 331
# Africa/Lusaka 67
# Africa/Harare 64

# %%
"""
This cell creates all the geojson files in ../data/WorldCitiesGeo/ 
Notice it uses two data structures:
    geojson = {
        "type": "FeatureCollection", 
        "features": []
    }
  
and

    tempList = []
    
The geojson var has the overall structure, and the tempList held features that were points:

            {
                "type": "Feature",
                "properties": {"name": city["city-name"]},
                "geometry": {
                    "coordinates": [float(city["lon"]), float(city["lat"])],
                    "type": "Point",
                },
            }
After one timezone completed, it wrote out the file and re-used the vars.
"""

import json

for timezone, citylist in cities.items():
    geojson = {"type": "FeatureCollection", "features": []}
    tempList = []
    print(f"Processing {timezone} ....")
    for city in citylist:
        tempList.append(
            {
                "type": "Feature",
                "properties": {"name": city["city-name"]},
                "geometry": {
                    "coordinates": [float(city["lon"]), float(city["lat"])],
                    "type": "Point",
                },
            }
        )
    geojson['features'] = tempList
    timezone = timezone.replace("/","-")
    with open(f"../data/WorldCitiesGeo/{timezone}.geojson","w") as f:
        json.dump(geojson,f,indent=2)
# Out:
# Processing Europe/Andorra ....
# Processing Asia/Dubai ....
# Processing Asia/Kabul ....
# Processing America/Antigua ....
# Processing America/Anguilla ....
# Processing Europe/Tirane ....
# Processing Asia/Yerevan ....
# Processing Africa/Luanda ....
# Processing Antarctica/McMurdo ....
# Processing America/Argentina/Buenos_Aires ....
# Processing America/Argentina/Cordoba ....
# Processing America/Argentina/San_Juan ....
# Processing America/Argentina/Salta ....
# Processing America/Argentina/Jujuy ....
# Processing America/Argentina/Tucuman ....
# Processing America/Argentina/Rio_Gallegos ....
# Processing America/Argentina/La_Rioja ....
# Processing America/Argentina/Mendoza ....
# Processing America/Argentina/San_Luis ....
# Processing America/Argentina/Ushuaia ....
# Processing America/Argentina/Catamarca ....
# Processing Pacific/Pago_Pago ....
# Processing Europe/Vienna ....
# Processing Australia/Perth ....
# Processing Australia/Adelaide ....
# Processing Australia/Darwin ....
# Processing Australia/Brisbane ....
# Processing Australia/Sydney ....
# Processing Australia/Melbourne ....
# Processing Australia/Hobart ....
# Processing Australia/Currie ....
# Processing Australia/Broken_Hill ....
# Processing America/Aruba ....
# Processing Europe/Mariehamn ....
# Processing Asia/Baku ....
# Processing Europe/Sarajevo ....
# Processing America/Barbados ....
# Processing Asia/Dhaka ....
# Processing Europe/Brussels ....
# Processing Africa/Ouagadougou ....
# Processing Europe/Sofia ....
# Processing Asia/Bahrain ....
# Processing Africa/Bujumbura ....
# Processing Africa/Porto-Novo ....
# Processing America/St_Barthelemy ....
# Processing Atlantic/Bermuda ....
# Processing Asia/Brunei ....
# Processing America/La_Paz ....
# Processing America/Kralendijk ....
# Processing America/Fortaleza ....
# Processing America/Recife ....
# Processing America/Belem ....
# Processing America/Maceio ....
# Processing America/Manaus ....
# Processing America/Bahia ....
# Processing America/Santarem ....
# Processing America/Araguaina ....
# Processing America/Noronha ....
# Processing America/Sao_Paulo ....
# Processing America/Cuiaba ....
# Processing America/Campo_Grande ....
# Processing America/Rio_Branco ....
# Processing America/Porto_Velho ....
# Processing America/Eirunepe ....
# Processing America/Boa_Vista ....
# Processing America/Nassau ....
# Processing Asia/Thimphu ....
# Processing Africa/Gaborone ....
# Processing Europe/Minsk ....
# Processing America/Belize ....
# Processing America/Vancouver ....
# Processing America/Toronto ....
# Processing America/Edmonton ....
# Processing America/Halifax ....
# Processing America/Winnipeg ....
# Processing America/Regina ....
# Processing America/Atikokan ....
# Processing America/St_Johns ....
# Processing America/Moncton ....
# Processing America/Dawson_Creek ....
# Processing America/Iqaluit ....
# Processing America/Creston ....
# Processing America/Yellowknife ....
# Processing America/Fort_Nelson ....
# Processing America/Cambridge_Bay ....
# Processing America/Glace_Bay ....
# Processing America/Whitehorse ....
# Processing America/Goose_Bay ....
# Processing America/Inuvik ....
# Processing America/Pangnirtung ....
# Processing America/Rankin_Inlet ....
# Processing America/Blanc-Sablon ....
# Processing America/Swift_Current ....
# Processing America/Thunder_Bay ....
# Processing America/Detroit ....
# Processing America/Dawson ....
# Processing Indian/Cocos ....
# Processing Africa/Lubumbashi ....
# Processing Africa/Kinshasa ....
# Processing Africa/Bangui ....
# Processing Africa/Brazzaville ....
# Processing Europe/Zurich ....
# Processing Europe/Rome ....
# Processing Africa/Abidjan ....
# Processing Pacific/Rarotonga ....
# Processing America/Santiago ....
# Processing Pacific/Easter ....
# Processing Africa/Douala ....
# Processing Asia/Shanghai ....
# Processing Asia/Urumqi ....
# Processing Asia/Yakutsk ....
# Processing America/Bogota ....
# Processing America/Costa_Rica ....
# Processing America/Havana ....
# Processing Atlantic/Cape_Verde ....
# Processing America/Curacao ....
# Processing Indian/Christmas ....
# Processing Asia/Nicosia ....
# Processing Europe/Prague ....
# Processing Europe/Berlin ....
# Processing Europe/Busingen ....
# Processing Africa/Djibouti ....
# Processing Europe/Copenhagen ....
# Processing America/Dominica ....
# Processing America/Santo_Domingo ....
# Processing Africa/Algiers ....
# Processing America/Guayaquil ....
# Processing Pacific/Galapagos ....
# Processing Europe/Tallinn ....
# Processing Africa/Cairo ....
# Processing Africa/El_Aaiun ....
# Processing Africa/Casablanca ....
# Processing Africa/Asmara ....
# Processing Europe/Madrid ....
# Processing Atlantic/Canary ....
# Processing Europe/Lisbon ....
# Processing Africa/Ceuta ....
# Processing Africa/Addis_Ababa ....
# Processing Europe/Helsinki ....
# Processing Pacific/Fiji ....
# Processing Atlantic/Stanley ....
# Processing Pacific/Chuuk ....
# Processing Pacific/Kosrae ....
# Processing Pacific/Pohnpei ....
# Processing Atlantic/Faroe ....
# Processing Europe/Paris ....
# Processing Africa/Libreville ....
# Processing Europe/London ....
# Processing America/Grenada ....
# Processing Asia/Tbilisi ....
# Processing America/Cayenne ....
# Processing Europe/Guernsey ....
# Processing Africa/Accra ....
# Processing Europe/Gibraltar ....
# Processing America/Godthab ....
# Processing Africa/Banjul ....
# Processing Africa/Conakry ....
# Processing America/Guadeloupe ....
# Processing Africa/Malabo ....
# Processing Europe/Athens ....
# Processing Atlantic/South_Georgia ....
# Processing America/Guatemala ....
# Processing Pacific/Guam ....
# Processing Africa/Bissau ....
# Processing America/Guyana ....
# Processing Asia/Hong_Kong ....
# Processing America/Tegucigalpa ....
# Processing Europe/Zagreb ....
# Processing America/Port-au-Prince ....
# Processing Europe/Budapest ....
# Processing Asia/Jakarta ....
# Processing Asia/Makassar ....
# Processing Asia/Jayapura ....
# Processing Asia/Pontianak ....
# Processing Europe/Dublin ....
# Processing Asia/Jerusalem ....
# Processing Europe/Isle_of_Man ....
# Processing Asia/Kolkata ....
# Processing Asia/Kathmandu ....
# Processing Asia/Rangoon ....
# Processing Asia/Baghdad ....
# Processing Asia/Tehran ....
# Processing Atlantic/Reykjavik ....
# Processing Europe/Jersey ....
# Processing America/Jamaica ....
# Processing Asia/Amman ....
# Processing Asia/Tokyo ....
# Processing Africa/Nairobi ....
# Processing Asia/Bishkek ....
# Processing Asia/Dushanbe ....
# Processing Asia/Phnom_Penh ....
# Processing Pacific/Tarawa ....
# Processing Pacific/Kiritimati ....
# Processing Indian/Comoro ....
# Processing America/St_Kitts ....
# Processing Asia/Pyongyang ....
# Processing Asia/Seoul ....
# Processing Asia/Kuwait ....
# Processing America/Cayman ....
# Processing Asia/Oral ....
# Processing Asia/Aqtau ....
# Processing Asia/Aqtobe ....
# Processing Asia/Almaty ....
# Processing Asia/Qyzylorda ....
# Processing Asia/Vientiane ....
# Processing Asia/Beirut ....
# Processing America/St_Lucia ....
# Processing Europe/Vaduz ....
# Processing Asia/Colombo ....
# Processing Africa/Monrovia ....
# Processing Africa/Maseru ....
# Processing Europe/Vilnius ....
# Processing Europe/Luxembourg ....
# Processing Europe/Riga ....
# Processing Africa/Tripoli ....
# Processing Europe/Monaco ....
# Processing Europe/Chisinau ....
# Processing Europe/Kiev ....
# Processing Europe/Podgorica ....
# Processing America/Marigot ....
# Processing Indian/Antananarivo ....
# Processing Pacific/Majuro ....
# Processing Pacific/Kwajalein ....
# Processing Europe/Skopje ....
# Processing Africa/Bamako ....
# Processing Asia/Hovd ....
# Processing Asia/Ulaanbaatar ....
# Processing Asia/Choibalsan ....
# Processing Asia/Macau ....
# Processing Pacific/Saipan ....
# Processing America/Martinique ....
# Processing Africa/Nouakchott ....
# Processing America/Montserrat ....
# Processing Europe/Malta ....
# Processing Indian/Mauritius ....
# Processing Indian/Maldives ....
# Processing Africa/Blantyre ....
# Processing America/Monterrey ....
# Processing America/Mexico_City ....
# Processing America/Matamoros ....
# Processing America/Merida ....
# Processing America/Cancun ....
# Processing America/Hermosillo ....
# Processing America/Chihuahua ....
# Processing America/Mazatlan ....
# Processing America/Tijuana ....
# Processing America/Bahia_Banderas ....
# Processing America/Ojinaga ....
# Processing Asia/Kuala_Lumpur ....
# Processing Asia/Kuching ....
# Processing Africa/Maputo ....
# Processing Africa/Windhoek ....
# Processing Pacific/Noumea ....
# Processing Africa/Niamey ....
# Processing Pacific/Norfolk ....
# Processing Africa/Lagos ....
# Processing America/Managua ....
# Processing Europe/Amsterdam ....
# Processing Europe/Oslo ....
# Processing Pacific/Nauru ....
# Processing Pacific/Niue ....
# Processing Pacific/Auckland ....
# Processing Pacific/Chatham ....
# Processing Asia/Muscat ....
# Processing America/Panama ....
# Processing America/Lima ....
# Processing Pacific/Marquesas ....
# Processing Pacific/Gambier ....
# Processing Pacific/Tahiti ....
# Processing Pacific/Port_Moresby ....
# Processing Pacific/Bougainville ....
# Processing Asia/Manila ....
# Processing Asia/Karachi ....
# Processing Europe/Warsaw ....
# Processing America/Miquelon ....
# Processing Pacific/Pitcairn ....
# Processing America/Puerto_Rico ....
# Processing Asia/Gaza ....
# Processing Asia/Hebron ....
# Processing Atlantic/Madeira ....
# Processing Atlantic/Azores ....
# Processing Pacific/Palau ....
# Processing America/Asuncion ....
# Processing Asia/Qatar ....
# Processing Indian/Reunion ....
# Processing Europe/Bucharest ....
# Processing Europe/Belgrade ....
# Processing Europe/Moscow ....
# Processing Asia/Yekaterinburg ....
# Processing Europe/Kirov ....
# Processing Europe/Kaliningrad ....
# Processing Europe/Volgograd ....
# Processing Europe/Samara ....
# Processing Europe/Ulyanovsk ....
# Processing Europe/Astrakhan ....
# Processing Asia/Novokuznetsk ....
# Processing Asia/Tomsk ....
# Processing Asia/Krasnoyarsk ....
# Processing Asia/Barnaul ....
# Processing Asia/Omsk ....
# Processing Asia/Novosibirsk ....
# Processing Asia/Irkutsk ....
# Processing Asia/Chita ....
# Processing Asia/Vladivostok ....
# Processing Asia/Kamchatka ....
# Processing Asia/Magadan ....
# Processing Asia/Sakhalin ....
# Processing Asia/Anadyr ....
# Processing Africa/Kigali ....
# Processing Asia/Riyadh ....
# Processing Pacific/Guadalcanal ....
# Processing Indian/Mahe ....
# Processing Africa/Khartoum ....
# Processing Europe/Stockholm ....
# Processing Asia/Singapore ....
# Processing Atlantic/St_Helena ....
# Processing Europe/Ljubljana ....
# Processing Arctic/Longyearbyen ....
# Processing Europe/Bratislava ....
# Processing Africa/Freetown ....
# Processing Europe/San_Marino ....
# Processing Africa/Dakar ....
# Processing Africa/Mogadishu ....
# Processing America/Paramaribo ....
# Processing Africa/Juba ....
# Processing Africa/Sao_Tome ....
# Processing America/El_Salvador ....
# Processing America/Lower_Princes ....
# Processing Asia/Damascus ....
# Processing Africa/Mbabane ....
# Processing America/Grand_Turk ....
# Processing Africa/Ndjamena ....
# Processing Indian/Kerguelen ....
# Processing Africa/Lome ....
# Processing Asia/Bangkok ....
# Processing Pacific/Fakaofo ....
# Processing Asia/Dili ....
# Processing Asia/Ashgabat ....
# Processing Africa/Tunis ....
# Processing Pacific/Tongatapu ....
# Processing Europe/Istanbul ....
# Processing America/Port_of_Spain ....
# Processing Pacific/Funafuti ....
# Processing Asia/Taipei ....
# Processing Africa/Dar_es_Salaam ....
# Processing Europe/Simferopol ....
# Processing Europe/Zaporozhye ....
# Processing Europe/Uzhgorod ....
# Processing Africa/Kampala ....
# Processing America/Chicago ....
# Processing America/New_York ....
# Processing America/Indiana/Indianapolis ....
# Processing America/Indiana/Vincennes ....
# Processing America/Indiana/Tell_City ....
# Processing America/Kentucky/Louisville ....
# Processing America/Indiana/Marengo ....
# Processing America/Indiana/Petersburg ....
# Processing America/Indiana/Vevay ....
# Processing America/Kentucky/Monticello ....
# Processing America/Indiana/Knox ....
# Processing America/Indiana/Winamac ....
# Processing America/Menominee ....
# Processing America/Phoenix ....
# Processing America/Los_Angeles ....
# Processing America/Denver ....
# Processing America/Juneau ....
# Processing America/Sitka ....
# Processing America/Metlakatla ....
# Processing America/Boise ....
# Processing America/North_Dakota/Beulah ....
# Processing America/North_Dakota/Center ....
# Processing America/North_Dakota/New_Salem ....
# Processing Pacific/Honolulu ....
# Processing America/Anchorage ....
# Processing America/Nome ....
# Processing America/Adak ....
# Processing America/Montevideo ....
# Processing Asia/Samarkand ....
# Processing Asia/Tashkent ....
# Processing Europe/Vatican ....
# Processing America/St_Vincent ....
# Processing America/Caracas ....
# Processing America/Tortola ....
# Processing America/St_Thomas ....
# Processing Asia/Ho_Chi_Minh ....
# Processing Pacific/Efate ....
# Processing Pacific/Wallis ....
# Processing Pacific/Apia ....
# Processing Asia/Aden ....
# Processing Indian/Mayotte ....
# Processing Africa/Johannesburg ....
# Processing Africa/Lusaka ....
# Processing Africa/Harare ....

# %% [markdown]
# ## Create GeoJson LineString Files
#
# - Using the following snippet of json, let me create a geojson file that connects all 4 cites with lines as an example.
# - I'm viewing my outputs in geojson.io
# - I'll do more Folium soon.

# %%
from rich import print
import json

colors = ["#00ffff", "#00ff00", "#ff00ff", "#0000ff", "#ffff00"]


def makeLineString(start, end, stroke):
  line = {
    "type": "Feature",
    "properties": {
      "from-city": start['city-name'],
      "to-city": end['city-name'],
      "stroke": stroke
      },
    "geometry": {
      "coordinates": [
        [
          float(start['lon']),
          float(start['lat'])
        ],
        [
          float(end['lon']),
          float(end['lat'])
        ]
      ],
      "type": "LineString"
    }
  }
  return line

cities = [
    {
        "city-name": "Tokyo",
        "lat": "35.6895",
        "lon": "139.69171",
        "time-zone": "Asia/Tokyo",
    },
    {
        "city-name": "Paris",
        "lat": "48.85341",
        "lon": "2.3488",
        "time-zone": "Europe/Paris",
    },
    {
        "city-name": "London",
        "lat": "51.50853",
        "lon": "-0.12574",
        "time-zone": "Europe/London",
    },
    {
        "city-name": "London",
        "lat": "51.50853",
        "lon": "-0.12574",
        "time-zone": "Europe/London",
    },
    {
      "city-name": "New York City",
      "lat": "40.71427",
      "lon": "-74.00597",
      "time-zone":"America/New York"
    },
]

geojson = {"type": "FeatureCollection", "features": []}
cityList = []
for i in range(len(cities)):
  line = makeLineString(cities[i], cities[(i+1)%len(cities)], colors[i % len(colors)])
  cityList.append(line)

geojson["features"] = cityList
print(geojson)
with open("../data/lineStrings.geojson", "w") as f:
  json.dump(geojson, f, indent=2)
# Out:
# {
#     'type': 'FeatureCollection',
#     'features': [
#         {
#             'type': 'Feature',
#             'properties': {'from-city': 'Tokyo', 'to-city': 'Paris', 'stroke': '#00ffff'},
#             'geometry': {'coordinates': [[139.69171, 35.6895], [2.3488, 48.85341]], 'type': 'LineString'}
#         },
#         {
#             'type': 'Feature',
#             'properties': {'from-city': 'Paris', 'to-city': 'London', 'stroke': '#00ff00'},
#             'geometry': {'coordinates': [[2.3488, 48.85341], [-0.12574, 51.50853]], 'type': 'LineString'}
#         },
#         {
#             'type': 'Feature',
#             'properties': {'from-city': 'London', 'to-city': 'London', 'stroke': '#ff00ff'},
#             'geometry': {'coordinates': [[-0.12574, 51.50853], [-0.12574, 51.50853]], 'type': 'LineString'}
#         },
#         {
#             'type': 'Feature',
#             'properties': {'from-city': 'London', 'to-city': 'New York City', 'stroke': '#0000ff'},
#             'geometry': {'coordinates': [[-0.12574, 51.50853], [-74.00597, 40.71427]], 'type': 'LineString'}
#         },
#         {
#             'type': 'Feature',
#             'properties': {'from-city': 'New York City', 'to-city': 'Tokyo', 'stroke': '#ffff00'},
#             'geometry': {'coordinates': [[-74.00597, 40.71427], [139.69171, 35.6895]], 'type': 'LineString'}
#         }
#     ]
# }

# %% [markdown]
# ## Completion verification
#
# This final cell verifies that the JSON grouping and GeoJSON export steps above created parseable output files.

# %%
from pathlib import Path
import json

data_dir = Path('../data')
timezone_path = data_dir / 'world_cities_by_time-zone.json'
line_path = data_dir / 'lineStrings.geojson'
geojson_dir = data_dir / 'WorldCitiesGeo'

assert timezone_path.exists(), f'Missing {timezone_path}'
assert line_path.exists(), f'Missing {line_path}'
assert geojson_dir.exists(), f'Missing {geojson_dir}'

with timezone_path.open() as f:
    cities_by_timezone = json.load(f)

geojson_files = sorted(geojson_dir.glob('*.geojson'))
with geojson_files[0].open() as f:
    sample_geojson = json.load(f)

with line_path.open() as f:
    line_geojson = json.load(f)

print('Time zones grouped:', len(cities_by_timezone))
print('GeoJSON point files:', len(geojson_files))
print('Sample point file type:', sample_geojson['type'])
print('LineString feature count:', len(line_geojson['features']))

assert len(cities_by_timezone) > 100
assert len(geojson_files) > 100
assert sample_geojson['type'] == 'FeatureCollection'
assert line_geojson['type'] == 'FeatureCollection'
# Out:
# Time zones grouped: 393
# GeoJSON point files: 393
# Sample point file type: FeatureCollection
# LineString feature count: 5
