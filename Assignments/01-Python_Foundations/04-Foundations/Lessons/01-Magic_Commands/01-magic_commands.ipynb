# %% [markdown]
# # 🧙 Magic Commands Demo Notebook
#
# This notebook introduces some of the most useful **IPython magic commands** in Jupyter.
# Run each cell and see what happens!

# %% [markdown]
# ## 1. Timing and Performance

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 23.4 ms, sys: 182 μs, total: 23.6 ms
# Wall time: 23.7 ms
# 499999500000

# %%
# %timeit sum(range(1_000_000))
# Out:
# 12 ms ± 561 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
# Out:
# CPU times: user 48.5 ms, sys: 456 μs, total: 49 ms
# Wall time: 48.9 ms

# %% [markdown]
# ## 2. Working with Files

# %%
# %pwd
# Out:
# '/Users/test/Downloads/SpatialData/4545_Spatial_Data/Assignments/01-Python_Foundations/04-Foundations/Lessons/01-Magic_Commands'

# %%
# %ls
# Out:
# 01-magic_commands.ipynb  _autogen.md              meta.yaml
# README.md                _header.md

# %%
# %cd ..
# %pwd
# Out:
# /Users/test/Downloads/SpatialData/4545_Spatial_Data/Assignments/01-Python_Foundations/04-Foundations/Lessons
# '/Users/test/Downloads/SpatialData/4545_Spatial_Data/Assignments/01-Python_Foundations/04-Foundations/Lessons'

# %% [markdown]
# ## 3. Variables in Memory

# %%
a = 42
b = [1, 2, 3]
c = {"name": "Graylian"}

# %who
# Out:
# a	 b	 c	 i	 total

# %%
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# a          int     42
# b          list    n=3
# c          dict    n=1
# i          int     999999
# total      int     499999500000

# %%
# %reset

# %% [markdown]
# ## 4. Debugging and Introspection

# %%
# Demonstrate an error without stopping the notebook run
try:
    1 / 0
except ZeroDivisionError as err:
    print(f"Caught expected error: {err}")
# Out:
# Caught expected error: division by zero

# %%
# %debug is interactive, so it is left commented for clean notebook execution.
# Run %debug manually after an exception if you want to inspect the traceback.
print("Use %debug manually after an exception to inspect the traceback.")
# Out:
# Use %debug manually after an exception to inspect the traceback.

# %% [markdown]
# ## 5. Writing and Running Files

# %%
# %%writefile hello.py
print("Hello from a file!")
# Out:
# Overwriting hello.py

# %%
# %run hello.py
# Out:
# Hello from a file!

# %% [markdown]
# ## 6. Output and Formatting

# %%
from IPython.utils.capture import capture_output

with capture_output() as cap:
    print("This will not display right away")

cap.show()
# Out:
# This will not display right away

# %%
# %%html
# <h1 style="color: maroon">Magics are Magical ✨</h1>
# Out:
# <h1 style="color: maroon">Magics are Magical ✨</h1>

# %%
# %%markdown
# # This is a Markdown cell inside code!
# **Bold text** and *italic* still work.
# Out:
# # This is a Markdown cell inside code!
# **Bold text** and *italic* still work.

# %% [markdown]
# ## 7. Discover More

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%code_wrap  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %timeit?

# %% [markdown]
# ✅ **Try It Yourself**:
# - Use `%timeit` to compare a list comprehension `[x**2 for x in range(1000)]` vs a generator `(x**2 for x in range(1000))`.
# - Use `%whos` after defining some variables to see their types.
# - Use `%%html` to make your own banner.

# %%
# %timeit [x**2 for x in range(1000)]
# %timeit (x**2 for x in range(1000))
# Out:
# 34.1 μs ± 1 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 116 ns ± 3.16 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
name = "Student"
scores = [90, 85, 88]
passed = True

# %whos
# Out:
# Variable         Type          Data/Info
# ----------------------------------------
# a                int           42
# b                list          n=3
# c                dict          n=1
# cap              CapturedIO    This will not display right away\n
# capture_output   type          <class 'IPython.utils.capture.capture_output'>
# i                int           999999
# name             str           Student
# passed           bool          True
# scores           list          n=3
# total            int           499999500000

# %%
# %%html
# <div style="background:#eee; padding:10px; border:1px solid #999">
#   <h2>My Banner</h2>
# </div>
# Out:
# <div style="background:#eee; padding:10px; border:1px solid #999">
#   <h2>My Banner</h2>
# </div>
