# %% [markdown]
# # 📝 Foundations Quiz
#
# This quiz covers material from the **Foundations** notebooks (01–08).
# Answer each question in the provided cell. Some questions require code, others are written answers.

# %% [markdown]
# ## Q1. Magics
# What does `%whos` display? Write your answer below.

# %% [markdown]
# `%whos` displays the variables currently defined in the notebook session, along with their type and a brief summary of their value.

# %% [markdown]
# ## Q2. Markdown
# Create a Markdown cell with a heading `## My Hobbies` and a bullet list of at least 3 hobbies.

# %% [markdown]
# ## My Hobbies
# - Reading
# - Hiking
# - Playing basketball

# %% [markdown]
# ## Q3. Files and Paths
# Use `%pwd` to print your current working directory.

# %%
# %pwd

# %% [markdown]
# ## Q4. File I/O
# Write Python code that saves `Hello World` to a file called `hello.txt`, then reads it back and prints the contents.

# %%
from pathlib import Path

hello_path = Path('hello.txt')
hello_path.write_text('Hello World')
print(hello_path.read_text())

# %% [markdown]
# ## Q5. Data I/O
# Load the file `students.csv` (or create a small CSV yourself) with Pandas and show the first 5 rows.

# %%
from pathlib import Path
import pandas as pd

students = pd.DataFrame(
    [
        {'name': 'Noah', 'major': 'CS', 'grade': 91},
        {'name': 'Ava', 'major': 'Math', 'grade': 95},
        {'name': 'Liam', 'major': 'GIS', 'grade': 88},
        {'name': 'Mia', 'major': 'CS', 'grade': 93},
        {'name': 'Ethan', 'major': 'Stats', 'grade': 90},
    ]
)

csv_path = Path('students.csv')
students.to_csv(csv_path, index=False)
print(pd.read_csv(csv_path).head())

# %% [markdown]
# ## Q6. Plotting
# Create a line plot of $y = x^2$ for $x$ values from 0 to 10.

# %%
import matplotlib.pyplot as plt

x = list(range(11))
y = [value ** 2 for value in x]

plt.plot(x, y, marker='o')
plt.title('y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q7. Shortcuts
# In Command mode, what keyboard shortcut deletes a cell?

# %% [markdown]
# In Command mode, press `dd` to delete the selected cell.

# %% [markdown]
# ## Q8. Help and Docs
# Use `?` to display the docstring for `len`. Show the result.

# %%
len?

# %% [markdown]
# ## Q9. Timing
# Compare the runtime of squaring numbers using a Python loop vs. NumPy. Use `%timeit` for each.

# %%
import numpy as np

nums = list(range(10000))
arr = np.arange(10000)

# %timeit [n ** 2 for n in nums]
# %timeit arr ** 2

# %% [markdown]
# ## Q10. Reflection
# Why is it useful to mix Markdown and code in Jupyter notebooks? Write 2–3 sentences.

# %% [markdown]
# Mixing Markdown and code makes a notebook easier to read because you can explain the purpose of each step right next to the code that performs it. It also turns the notebook into a reproducible report instead of just a loose collection of commands.
