# %% [markdown]
# # 📘 03 - File Loops and `with`
#
# Use `with open(...)` to read files and process content.

# %% [markdown]
# ## ✅ Learning Goals
# - Open and read files using `with`
# - Loop over lines in a file
# - Use `.strip()` and `.split()` to process text

# %%
# 📝 Sample file read
with open('sample.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# apple,banana,cherry
# this line has more than three words
# red,green,blue
# spatial data is pretty fun

# %%
# 🔍 Process each line
with open('sample.txt', 'r') as f:
    for line in f:
        parts = line.strip().split(',')
        print('Parts:', parts)
# Out:
# Parts: ['apple', 'banana', 'cherry']
# Parts: ['this line has more than three words']
# Parts: ['red', 'green', 'blue']
# Parts: ['spatial data is pretty fun']

# %% [markdown]
# ### ✏️ Your Turn
# Open a text file and print all lines that contain more than 3 words.

# %%
with open('sample.txt', 'r') as file:
    for line in file:
        if len(line.split()) > 3:
            print(line.strip())
# Out:
# this line has more than three words
# spatial data is pretty fun
